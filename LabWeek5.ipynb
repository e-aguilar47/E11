# %%
import pandas as pd
outside=pd.read_csv('outsidedata.csv')
import numpy as np
import matplotlib.pyplot as plt

# %%
display(outside)
# Out:
#              Time  pm10 standard  pm25 standard  pm100 standard  temperature  \
# 0    1.708129e+09              4              6               6    34.788008
# 1    1.708129e+09              4              6               7    23.958125
# 2    1.708129e+09              4              6               7    23.991523
# 3    1.708129e+09              4              6               7    24.028437
# 4    1.708129e+09              4              6               6    24.063398
# ..            ...            ...            ...             ...          ...
# 331  1.708129e+09              7             10              11    16.041719
# 332  1.708129e+09              7             10              11    16.038203
# 333  1.708129e+09              7             10              11    16.037813
# 334  1.708129e+09              7              9               9    16.038789
# 335  1.708129e+09              7              9               9    16.039375
#
# ...

# %%
data_pm10_out=outside.loc[:,'Time':'pm10 standard']

plt.hist(data_pm10_out['pm10 standard'],bins=7)
# Out:
# (array([ 9., 11., 52., 74., 68., 96., 26.]),
#  array([1.        , 1.85714286, 2.71428571, 3.57142857, 4.42857143,
#         5.28571429, 6.14285714, 7.        ]),
#  <BarContainer object of 7 artists>)

# %%
data_pm25_out=outside.loc[:,['Time','pm25 standard']]

plt.hist(data_pm25_out['pm25 standard'],bins=8)
# Out:
# (array([ 8., 34., 45., 44., 44., 42., 89., 30.]),
#  array([ 3.   ,  3.875,  4.75 ,  5.625,  6.5  ,  7.375,  8.25 ,  9.125,
#         10.   ]),
#  <BarContainer object of 8 artists>)

# %%
data_pm100_out=outside.loc[:,['Time','pm100 standard']]

plt.hist(data_pm100_out['pm100 standard'],bins=8)
# Out:
# (array([26., 42., 31., 76., 21., 38., 51., 51.]),
#  array([ 4.,  5.,  6.,  7.,  8.,  9., 10., 11., 12.]),
#  <BarContainer object of 8 artists>)

# %%
data_temp_out=outside.loc[:,['Time','temperature']]

plt.hist(data_temp_out['temperature'],bins=8)
# Out:
# (array([163.,  50.,  46.,  76.,   0.,   0.,   0.,   1.]),
#  array([16.0378125 , 18.38158691, 20.72536133, 23.06913574, 25.41291016,
#         27.75668457, 30.10045898, 32.4442334 , 34.78800781]),
#  <BarContainer object of 8 artists>)

# %%
data_gas_out=outside.loc[:,['Time','gas']]

plt.hist(data_gas_out['gas'],bins=8)
# Out:
# (array([ 12.,  17.,  93., 213.,   0.,   0.,   0.,   1.]),
#  array([ 76383.   , 140753.625, 205124.25 , 269494.875, 333865.5  ,
#         398236.125, 462606.75 , 526977.375, 591348.   ]),
#  <BarContainer object of 8 artists>)

# %%
data_humidity_out=outside.loc[:,['Time','humidity']]

plt.hist(data_humidity_out['humidity'],bins=8)
# Out:
# (array([168., 145.,  22.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 39.68566315,  47.22495526,  54.76424736,  62.30353947,
#          69.84283157,  77.38212368,  84.92141579,  92.46070789,
#         100.        ]),
#  <BarContainer object of 8 artists>)

# %%
data_pressure_out=outside.loc[:,['Time','pressure']]

plt.hist(data_pressure_out['pressure'],bins=8)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0., 335.]),
#  array([ 692.6947882 ,  732.19569325,  771.6965983 ,  811.19750336,
#          850.69840841,  890.19931346,  929.70021852,  969.20112357,
#         1008.70202863]),
#  <BarContainer object of 8 artists>)

# %%
data_alt_out=outside.loc[:,['Time','altitude']]

plt.hist(data_alt_out['altitude'],bins=8)
# Out:
# (array([335.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  37.93396504,  420.07922497,  802.2244849 , 1184.36974483,
#         1566.51500476, 1948.66026469, 2330.80552462, 2712.95078454,
#         3095.09604447]),
#  <BarContainer object of 8 artists>)

# %%
inside=pd.read_csv('insidedata.csv')

# %%
data_pm10_in=inside.loc[:,'Time':'pm10 standard']

plt.hist(data_pm10_in['pm10 standard'],bins=7)
# Out:
# (array([  3.,   0.,  73.,   0., 184.,   0.,  37.]),
#  array([1.        , 1.42857143, 1.85714286, 2.28571429, 2.71428571,
#         3.14285714, 3.57142857, 4.        ]),
#  <BarContainer object of 7 artists>)

# %%
data_pm25_in=inside.loc[:,['Time','pm25 standard']]

plt.hist(data_pm25_in['pm25 standard'],bins=8)
# Out:
# (array([ 17.,   0.,  54.,   0., 100.,   0., 116.,  10.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 8 artists>)

# %%
data_pm100_in=inside.loc[:,['Time','pm100 standard']]

plt.hist(data_pm100_in['pm100 standard'],bins=8)
# Out:
# (array([ 3., 52.,  0., 93., 76.,  0., 54., 19.]),
#  array([2.   , 2.625, 3.25 , 3.875, 4.5  , 5.125, 5.75 , 6.375, 7.   ]),
#  <BarContainer object of 8 artists>)

# %%
data_temp_in=inside.loc[:,['Time','temperature']]

plt.hist(data_temp_in['temperature'],bins=8)
# Out:
# (array([296.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([23.88820313, 25.25067871, 26.6131543 , 27.97562989, 29.33810547,
#         30.70058106, 32.06305664, 33.42553223, 34.78800781]),
#  <BarContainer object of 8 artists>)

# %%
data_gas_in=inside.loc[:,['Time','gas']]

plt.hist(data_gas_in['gas'],bins=8)
# Out:
# (array([  4.,   6.,   6.,  12.,  20.,  24.,  61., 164.]),
#  array([ 37827.   ,  65598.125,  93369.25 , 121140.375, 148911.5  ,
#         176682.625, 204453.75 , 232224.875, 259996.   ]),
#  <BarContainer object of 8 artists>)

# %%
data_humidity_in=inside.loc[:,['Time','humidity']]

plt.hist(data_humidity_in['humidity'],bins=8)
# Out:
# (array([296.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 40.22761421,  47.69916243,  55.17071066,  62.64225888,
#          70.11380711,  77.58535533,  85.05690355,  92.52845178,
#         100.        ]),
#  <BarContainer object of 8 artists>)

# %%
data_pressure_in=inside.loc[:,['Time','pressure']]

plt.hist(data_pressure_in['pressure'],bins=8)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0., 296.]),
#  array([ 692.6947882 ,  732.19647842,  771.69816865,  811.19985888,
#          850.7015491 ,  890.20323932,  929.70492955,  969.20661978,
#         1008.70831   ]),
#  <BarContainer object of 8 artists>)

# %%
data_alt_in=inside.loc[:,['Time','altitude']]

plt.hist(data_alt_in['altitude'],bins=8)
# Out:
# (array([296.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  37.88147862,  420.03329929,  802.18511997, 1184.33694064,
#         1566.48876131, 1948.64058198, 2330.79240265, 2712.94422333,
#         3095.096044  ]),
#  <BarContainer object of 8 artists>)

# %%
plt.hist(data_pm10_in["pm10 standard"],bins=8,label='inside data')
plt.hist(data_pm10_out["pm10 standard"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_pm25_in["pm25 standard"],bins=8,label='inside data')
plt.hist(data_pm25_out["pm25 standard"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_pm100_in["pm100 standard"],bins=8,label='inside data')
plt.hist(data_pm100_out["pm100 standard"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_temp_in["temperature"],bins=8,label='inside data')
plt.hist(data_temp_out["temperature"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_gas_in["gas"],bins=8,label='inside data')
plt.hist(data_gas_out["gas"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_humidity_in["humidity"],bins=8,label='inside data')
plt.hist(data_humidity_out["humidity"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_pressure_in["pressure"],bins=8,label='inside data')
plt.hist(data_pressure_out["pressure"],bins=8,label='outside')
plt.legend()

# %%
plt.hist(data_alt_in["altitude"],bins=8,label='inside data')
plt.hist(data_alt_out["altitude"],bins=8,label='outside')
plt.legend()
