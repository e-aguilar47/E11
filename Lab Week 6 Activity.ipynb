# %% [markdown]
# ### Step 1 [DONE]

# %%
import pandas as pd
outside=pd.read_csv('outsidedata.csv')
inside=pd.read_csv('insidedata.csv')
import numpy as np
import matplotlib.pyplot as plt

# %%
data_pm10_out=outside.loc[:,'Time':'pm10 standard']
data_pm25_out=outside.loc[:,['Time','pm25 standard']]
data_pm100_out=outside.loc[:,['Time','pm100 standard']]
data_temp_out=outside.loc[:,['Time','temperature']]
data_gas_out=outside.loc[:,['Time','gas']]
data_humidity_out=outside.loc[:,['Time','humidity']]
data_pressure_out=outside.loc[:,['Time','pressure']]
data_alt_out=outside.loc[:,['Time','altitude']]

data_pm10_in=inside.loc[:,'Time':'pm10 standard']
data_pm25_in=inside.loc[:,['Time','pm25 standard']]
data_pm100_in=inside.loc[:,['Time','pm100 standard']]
data_temp_in=inside.loc[:,['Time','temperature']]
data_gas_in=inside.loc[:,['Time','gas']]
data_humidity_in=inside.loc[:,['Time','humidity']]
data_pressure_in=inside.loc[:,['Time','pressure']]
data_alt_in=inside.loc[:,['Time','altitude']]

# %%
plt.hist(data_pm10_in["pm10 standard"],bins=8,label='inside pm10')
plt.hist(data_pm10_out["pm10 standard"],bins=8,label='outside pm10')
plt.legend()
print('inside pm10 mean:',np.mean(data_pm10_in["pm10 standard"]))
print('outside pm10 mean:',np.mean(data_pm10_out["pm10 standard"]))
print('inside pm10 σ',np.std(data_pm10_in["pm10 standard"]))
print('outside pm10 σ',np.std(data_pm10_out["pm10 standard"]))
# Out:
# inside pm10 mean: 2.8585858585858586
# outside pm10 mean: 4.705357142857143
# inside pm10 σ 0.6251211493642753
# outside pm10 σ 1.4390704228677555

# %%
plt.hist(data_pm25_in["pm25 standard"],bins=8,label='inside pm25')
plt.hist(data_pm25_out["pm25 standard"],bins=8,label='outside pm25')
plt.legend()
print('inside pm25 mean:',np.mean(data_pm25_in["pm25 standard"]))
print('outside pm25 mean:',np.mean(data_pm25_out["pm25 standard"]))
print('inside pm25 σ',np.std(data_pm25_in["pm25 standard"]))
print('outside pm25 σ',np.std(data_pm25_out["pm25 standard"]))
# Out:
# inside pm25 mean: 4.161616161616162
# outside pm25 mean: 7.125
# inside pm25 σ 0.953890534773983
# outside pm25 σ 1.9826254238833345

# %%
plt.hist(data_pm100_in["pm100 standard"],bins=8,label='inside pm100')
plt.hist(data_pm100_out["pm100 standard"],bins=8,label='outside pm100')
plt.legend()
print('inside pm100 mean:',np.mean(data_pm100_in["pm100 standard"]))
print('outside pm100 mean:',np.mean(data_pm100_out["pm100 standard"]))
print('inside pm100 σ',np.std(data_pm100_in["pm100 standard"]))
print('outside pm100 σ',np.std(data_pm100_out["pm100 standard"]))
# Out:
# inside pm100 mean: 4.616161616161616
# outside pm100 mean: 7.848214285714286
# inside pm100 σ 1.1809977295405263
# outside pm100 σ 2.3498093441983

# %%
plt.hist(data_temp_in["temperature"],bins=8,label='inside temperature')
plt.hist(data_temp_out["temperature"],bins=8,label='outside temperature')
plt.legend()
print('inside temperature mean:',np.mean(data_temp_in["temperature"]))
print('outside temperature mean:',np.mean(data_temp_out["temperature"]))
print('inside temperature σ',np.std(data_temp_in["temperature"]))
print('outside temperature σ',np.std(data_temp_out["temperature"]))
# Out:
# inside temperature mean: 24.144822707239058
# outside temperature mean: 19.543896834285714
# inside temperature σ 0.6228942543438271
# outside temperature σ 3.1783126469798617

# %%
plt.hist(data_gas_in["gas"],bins=8,label='inside gas')
plt.hist(data_gas_out["gas"],bins=8,label='outside gas')
plt.legend()
print('inside gas mean:',np.mean(data_gas_in["gas"]))
print('outside gas mean:',np.mean(data_gas_in["gas"]))
print('inside gas σ',np.std(data_gas_in["gas"]))
print('outside gas σ',np.std(data_gas_out["gas"]))
# Out:
# inside gas mean: 219140.95286195286
# outside gas mean: 219140.95286195286
# inside gas σ 45898.31881039516
# outside gas σ 51383.84255390864

# %%
plt.hist(data_humidity_in["humidity"],bins=8,label='inside humidity')
plt.hist(data_humidity_out["humidity"],bins=8,label='outside humidity')
plt.legend()
print('inside humidity mean:',np.mean(data_humidity_in["humidity"]))
print('outside humidity mean:',np.mean(data_humidity_out["humidity"]))
print('inside humidity σ',np.std(data_humidity_in["humidity"]))
print('outside humidity σ',np.std(data_humidity_out["humidity"]))
# Out:
# inside humidity mean: 40.71253394030303
# outside humidity mean: 47.12059092799071
# inside humidity σ 3.457255782076537
# outside humidity σ 6.474078562498245

# %%
plt.hist(data_pressure_in["pressure"],bins=8,label='inside pressure')
plt.hist(data_pressure_out["pressure"],bins=8,label='outside pressure')
plt.legend()
print('inside pressure mean:',np.mean(data_pressure_in["pressure"]))
print('outside pressure mean:',np.mean(data_pressure_out["pressure"]))
print('inside pressure σ',np.std(data_pressure_in["pressure"]))
print('outside pressure σ',np.std(data_pressure_out["pressure"]))
# Out:
# inside pressure mean: 1007.5835100208753
# outside pressure mean: 1006.6889426127564
# inside pressure σ 18.302564310572212
# outside pressure σ 17.162579931116436

# %%
plt.hist(data_alt_in["altitude"],bins=8,label='inside altitude')
plt.hist(data_alt_out["altitude"],bins=8,label='outside altitude')
plt.legend()
print('inside altitude mean:',np.mean(data_alt_in["altitude"]))
print('outside altitude mean:',np.mean(data_alt_out["altitude"]))

print('inside altitude σ',np.std(data_alt_in["altitude"]))
print('outside altitude σ',np.std(data_alt_out["altitude"]))
# Out:
# inside altitude mean: 48.68303618400673
# outside altitude mean: 55.99998716891993
# inside altitude σ 177.0693695908451
# outside altitude σ 166.0958991093627

# %% [markdown]
# ### Step 2

# %%
outside2=pd.read_csv('LAB6_outdoors.csv')
inside2=pd.read_csv('LAB6_indoors.csv')

# %%
data_pm10_out2=outside2.loc[:,'Time':'PM10']
data_pm25_out2=outside2.loc[:,['Time','PM2.5']]
data_temp_out2=outside2.loc[:,['Time','Temperature']]
data_gas_out2=outside2.loc[:,['Time','Gas']]
data_humidity_out2=outside2.loc[:,['Time','Humidity']]
data_pressure_out2=outside2.loc[:,['Time','Pressure']]
data_alt_out2=outside2.loc[:,['Time','Altitude']]

data_pm10_in2=inside2.loc[:,'Time':'PM10']
data_pm25_in2=inside2.loc[:,['Time','PM2.5']]
data_temp_in2=inside2.loc[:,['Time','Temperature']]
data_gas_in2=inside2.loc[:,['Time','Gas']]
data_humidity_in2=inside2.loc[:,['Time','Humidity']]
data_pressure_in2=inside2.loc[:,['Time','Pressure']]
data_alt_in2=inside2.loc[:,['Time','Altitude']]

# %%
plt.hist(data_pm10_in["pm10 standard"],bins=8,label='inside pm10')
plt.hist(data_pm10_out["pm10 standard"],bins=8,label='outside pm10')
plt.hist(data_pm10_in2["PM10"],bins=8,label='other group inside pm10')
plt.hist(data_pm10_out2["PM10"],bins=8,label='other group outside pm10')
plt.legend()

# %% [markdown]
# ### Step 3

# %%
etcheverry=pd.read_csv('etchdata.csv')

# %%
data_pm10_etch=etcheverry.loc[:,'Time':'pm10 standard']
data_pm25_etch=etcheverry.loc[:,['Time','pm25 standard']]
data_pm100_etch=etcheverry.loc[:,['Time','pm100 standard']]
data_temp_etch=etcheverry.loc[:,['Time','temperature']]
data_gas_etch=etcheverry.loc[:,['Time','gas']]
data_humidity_etch=etcheverry.loc[:,['Time','humidity']]
data_pressure_etch=etcheverry.loc[:,['Time','pressure']]
data_alt_etch=etcheverry.loc[:,['Time','altitude']]

# %%
plt.hist(data_pm10_etch["pm10 standard"],bins=8,label='etcheverry pm10')
plt.hist(data_pm10_out["pm10 standard"],bins=8,label='outside pm10')
plt.legend()
print('etcheverry pm10 mean:',np.mean(data_pm10_etch["pm10 standard"]))
print('outside pm10 mean:',np.mean(data_pm10_out["pm10 standard"]))
print('etcheverry pm10 σ',np.std(data_pm10_etch["pm10 standard"]))
print('outside pm10 σ',np.std(data_pm10_out["pm10 standard"]))
# Out:
# etcheverry pm10 mean: 0.9324324324324325
# outside pm10 mean: 4.705357142857143
# etcheverry pm10 σ 1.5141769781337648
# outside pm10 σ 1.4390704228677555

# %%
plt.hist(data_pm25_etch["pm25 standard"],bins=8,label='etcheverry pm10')
plt.hist(data_pm25_out["pm25 standard"],bins=8,label='outside pm10')
plt.legend()
print('etcheverry pm25 mean:',np.mean(data_pm25_etch["pm25 standard"]))
print('outside pm25 mean:',np.mean(data_pm25_out["pm25 standard"]))
print('etcheverry pm25 σ',np.std(data_pm25_etch["pm25 standard"]))
print('outside pm25 σ',np.std(data_pm25_out["pm25 standard"]))
# Out:
# etcheverry pm25 mean: 1.5912162162162162
# outside pm25 mean: 7.125
# etcheverry pm25 σ 2.3391043866465075
# outside pm25 σ 1.9826254238833345

# %%
plt.hist(data_pm100_etch["pm100 standard"],bins=8,label='etcheverry pm100')
plt.hist(data_pm100_out["pm100 standard"],bins=8,label='outside pm100')
plt.legend()
print('etcheverry pm100 mean:',np.mean(data_pm100_etch["pm100 standard"]))
print('outside pm100 mean:',np.mean(data_pm100_out["pm100 standard"]))
print('etcheverry pm100 σ',np.std(data_pm100_etch["pm100 standard"]))
print('outside pm100 σ',np.std(data_pm100_out["pm100 standard"]))
# Out:
# etcheverry pm100 mean: 2.1587837837837838
# outside pm100 mean: 7.848214285714286
# etcheverry pm100 σ 3.1438147995375134
# outside pm100 σ 2.3498093441983

# %%
plt.hist(data_temp_etch["temperature"],bins=8,label='etcheverry temperature')
plt.hist(data_temp_out["temperature"],bins=8,label='outside temperature')
plt.legend()
print('etcheverry temperature mean:',np.mean(data_temp_etch["temperature"]))
print('outside temperature mean:',np.mean(data_temp_out["temperature"]))
print('etcheverry temperature σ',np.std(data_temp_etch["temperature"]))
print('outside temperature σ',np.std(data_temp_out["temperature"]))
# Out:
# etcheverry temperature mean: 22.56772698608108
# outside temperature mean: 19.543896834285714
# etcheverry temperature σ 0.8086209480445145
# outside temperature σ 3.1783126469798617

# %%
plt.hist(data_gas_etch["gas"],bins=8,label='etcheverry gas')
plt.hist(data_gas_out["gas"],bins=8,label='outside gas')
plt.legend()
print('etcheverry gas mean:',np.mean(data_gas_etch["gas"]))
print('outside gas mean:',np.mean(data_gas_out["gas"]))
print('etcheverry gas σ',np.std(data_gas_etch["gas"]))
print('outside gas σ',np.std(data_gas_out["gas"]))
# Out:
# etcheverry gas mean: 188782.02364864864
# outside gas mean: 271626.88095238095
# etcheverry gas σ 76821.65252618666
# outside gas σ 51383.84255390864

# %%
plt.hist(data_humidity_etch["humidity"],bins=8,label='etcheverry humidity')
plt.hist(data_humidity_out["humidity"],bins=8,label='outside humidity')
plt.legend()
print('etcheverry humidity mean:',np.mean(data_humidity_etch["humidity"]))
print('outside humidity mean:',np.mean(data_humidity_out["humidity"]))
print('etcheverry humidity σ',np.std(data_humidity_etch["humidity"]))
print('outside humidity σ',np.std(data_humidity_out["humidity"]))
# Out:
# etcheverry humidity mean: 33.137604493971324
# outside humidity mean: 47.12059092799071
# etcheverry humidity σ 1.9203726369519862
# outside humidity σ 6.474078562498245

# %%
plt.hist(data_pressure_etch["pressure"],bins=8,label='etcheverry pressure')
plt.hist(data_pressure_out["pressure"],bins=8,label='outside pressure')
plt.legend()
print('etcheverry pressure mean:',np.mean(data_pressure_etch["pressure"]))
print('outside pressure mean:',np.mean(data_pressure_out["pressure"]))
print('etcheverry pressure σ',np.std(data_pressure_etch["pressure"]))
print('outside pressure σ',np.std(data_pressure_out["pressure"]))
# Out:
# etcheverry pressure mean: 1007.3250842308173
# outside pressure mean: 1006.6889426127564
# etcheverry pressure σ 0.3954179889480611
# outside pressure σ 17.162579931116436

# %%
plt.hist(data_alt_etch["altitude"],bins=8,label='etcheverry altitude')
plt.hist(data_alt_out["altitude"],bins=8,label='outside altitude')
plt.legend()
print('etcheverry altitude mean:',np.mean(data_alt_etch["altitude"]))
print('outside altitude mean:',np.mean(data_alt_out["altitude"]))
print('etcheverry altitude σ',np.std(data_alt_etch["altitude"]))
print('outside altitude σ',np.std(data_alt_out["altitude"]))
# Out:
# etcheverry altitude mean: 49.446692272693625
# outside altitude mean: 55.99998716891993
# etcheverry altitude σ 3.3085349854799304
# outside altitude σ 166.0958991093627

# %%
data_pm10_etch=etcheverry.loc[:,['temperature','humidity']]
data_pm25_etch=etcheverry.loc[:,['Time','pm25 standard']]
data_pm100_etch=etcheverry.loc[:,['Time','pm100 standard']]
data_temp_etch=etcheverry.loc[:,['Time','temperature']]
data_gas_etch=etcheverry.loc[:,['Time','gas']]
data_humidity_etch=etcheverry.loc[:,['Time','humidity']]
data_pressure_etch=etcheverry.loc[:,['Time','pressure']]
data_alt_etch=etcheverry.loc[:,['Time','altitude']]

# %% [markdown]
# ### Step 4

# %%
plt.plot(data_pm10_etch['temperature'],label='etcheverry temperatue')
plt.plot(data_pm10_etch['humidity'],label='etcheverry humidity')
plt.legend()

# %% [markdown]
# ### Step 4
